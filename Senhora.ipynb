# %%
import nbimporter
from src import EmotionAnalysis as ea
# Out:
# Importing Jupyter notebook from /home/ellen/Projetos/TextMining/src/EmotionAnalysis.ipynb

# %%
ea.analysis('books/senhora.txt')
# Out:
# quantidade de palavras: 88243
# quantidade de palavras após o filtro: 38415
# quantidade de palavras únicas: 12230
# quantidade de palavras únicas após o filtro: 10304
# 20 palavras mais frequentes:
# [('aurélia', 623), ('seixas', 457), ('moça', 270), ('marido', 216), ('ainda', 168), ('mulher', 167), ('casa', 144), ('havia', 137), ('fernando', 131), ('amor', 121), ('disse', 116), ('lemos', 111), ('senhor', 111), ('tempo', 110), ('alma', 110), ('casamento', 109), ('noite', 109), ('senhora', 102), ('onde', 102), ('pois', 100)]
#
#
# Palavra mais frequente: aurélia - 623 vezes
#
#
# N-grams da palavra de maior frequência
#
# não se recorda da aurélia
# se recorda da aurélia camargo
# recorda da aurélia camargo ,
# da aurélia camargo , que
# aurélia camargo , que atravessou
# vesti-la os noveleiros . aurélia
# os noveleiros . aurélia era
# noveleiros . aurélia era órfã
# . aurélia era órfã ;
# aurélia era órfã ; e
# . constava também que aurélia
# constava também que aurélia tinha
# ...

# %%
ea.analysis('books/diva.txt')
# Out:
# quantidade de palavras: 33699
# quantidade de palavras após o filtro: 13998
# quantidade de palavras únicas: 5760
# quantidade de palavras únicas após o filtro: 4947
# 20 palavras mais frequentes:
# [('emília', 259), ('mim', 124), ('ainda', 82), ('alma', 81), ('senhor', 72), ('coração', 69), ('amor', 65), ('então', 61), ('senhora', 59), ('disse', 56), ('olhos', 55), ('tão', 50), ('bem', 48), ('noite', 48), ('palavra', 48), ('olhar', 47), ('tempo', 45), ('menina', 45), ('pois', 45), ('vez', 44)]
#
#
# Palavra mais frequente: emília - 259 vezes
#
#
# N-grams da palavra de maior frequência
#
# emília tinha quatorze anos quando
# ou primores . era emília
# primores . era emília um
# . era emília um colibri
# era emília um colibri implume
# emília um colibri implume ;
# propriedade esse defeito de emília
# esse defeito de emília do
# defeito de emília do que
# de emília do que a
# emília do que a menina
# a fealdade da pobre emília
# fealdade da pobre emília .
# da pobre emília . a
# ...

# %%
ea.analysis('books/gaucho.txt')
# Out:
# quantidade de palavras: 82217
# quantidade de palavras após o filtro: 37411
# quantidade de palavras únicas: 11184
# quantidade de palavras únicas após o filtro: 9902
# 20 palavras mais frequentes:
# [('manuel', 417), ('gaúcho', 290), ('canho', 186), ('catita', 168), ('sobre', 157), ('homem', 140), ('onde', 140), ('então', 133), ('animal', 133), ('ainda', 123), ('moça', 119), ('tempo', 116), ('cavalo', 112), ('olhos', 110), ('bem', 108), ('momento', 100), ('porém', 99), ('casa', 99), ('coração', 98), ('dois', 98)]
#
#
# Palavra mais frequente: manuel - 417 vezes
#
#
# N-grams da palavra de maior frequência
#
# pode ser , chamo-me manuel
# ser , chamo-me manuel canho
# , chamo-me manuel canho ,
# chamo-me manuel canho , para
# manuel canho , para o
# me é estranho . manuel
# é estranho . manuel canho
# estranho . manuel canho ...
# . manuel canho ... de
# manuel canho ... de ponche-verde
# que faísca ! sr. manuel
# faísca ! sr. manuel canho
# ! sr. manuel canho .
# ...

# %%
ea.analysis('books/guarani.txt')
# Out:
# quantidade de palavras: 124108
# quantidade de palavras após o filtro: 55519
# quantidade de palavras únicas: 12109
# quantidade de palavras únicas após o filtro: 10455
# 20 palavras mais frequentes:
# [('peri', 728), ('cecília', 458), ('sobre', 412), ('índio', 338), ('antônio', 300), ('álvaro', 279), ('disse', 243), ('olhos', 227), ('senhora', 227), ('menina', 215), ('isabel', 196), ('havia', 194), ('fidalgo', 193), ('casa', 189), ('ainda', 180), ('tempo', 175), ('mariz', 175), ('loredano', 174), ('momento', 174), ('italiano', 173)]
#
#
# Palavra mais frequente: peri - 728 vezes
#
#
# N-grams da palavra de maior frequência
#
# animal selvagem . — peri
# selvagem . — peri !
# . — peri ! exclamou
# — peri ! exclamou cecília
# peri ! exclamou cecília rindo-se
# do que o teu peri
# que o teu peri .
# o teu peri . —
# teu peri . — prima
# peri . — prima ,
# quatro léguas daqui encontramos peri
# léguas daqui encontramos peri .
# daqui encontramos peri . —
# encontramos peri . — inda
# ...

# %%
ea.analysis('books/iracema.txt')
# Out:
# quantidade de palavras: 25895
# quantidade de palavras após o filtro: 12210
# quantidade de palavras únicas: 4033
# quantidade de palavras únicas após o filtro: 3693
# 20 palavras mais frequentes:
# [('iracema', 220), ('guerreiro', 219), ('cabana', 115), ('virgem', 111), ('guerreiros', 101), ('poti', 101), ('olhos', 94), ('irmão', 89), ('martim', 86), ('onde', 82), ('chefe', 74), ('estrangeiro', 72), ('araquém', 71), ('grande', 67), ('terra', 66), ('filha', 60), ('pajé', 60), ('mar', 59), ('branco', 58), ('coração', 57)]
#
#
# Palavra mais frequente: iracema - 220 vezes
#
#
# N-grams da palavra de maior frequência
#
# das vagas : — iracema
# vagas : — iracema !
# : — iracema ! o
# — iracema ! o moço
# iracema ! o moço guerreiro
# no horizonte , nasceu iracema
# horizonte , nasceu iracema .
# , nasceu iracema . iracema
# nasceu iracema . iracema ,
# iracema . iracema , a
# . iracema , a virgem
# iracema , a virgem dos
# pássaros ameigavam o canto iracema
# ...

# %%
ea.analysis('books/ubirajara.txt')
# Out:
# quantidade de palavras: 25674
# quantidade de palavras após o filtro: 11881
# quantidade de palavras únicas: 3607
# quantidade de palavras únicas após o filtro: 3255
# 20 palavras mais frequentes:
# [('guerreiro', 225), ('ubirajara', 168), ('chefe', 165), ('guerreiros', 157), ('elle', 145), ('grande', 143), ('nação', 121), ('itaquê', 115), ('arací', 97), ('virjem', 85), ('pojucan', 81), ('jurandir', 79), ('cabana', 79), ('espoza', 76), ('arco', 73), ('ella', 73), ('tocantim', 67), ('taba', 66), ('jaguarê', 63), ('mão', 62)]
#
#
# Palavra mais frequente: guerreiro - 225 vezes
#
#
# N-grams da palavra de maior frequência
#
# caçador pela gloria do guerreiro
# pela gloria do guerreiro .
# gloria do guerreiro . para
# do guerreiro . para ser
# guerreiro . para ser aclamado
# . para ser aclamado guerreiro
# para ser aclamado guerreiro por
# ser aclamado guerreiro por sua
# aclamado guerreiro por sua nação
# guerreiro por sua nação é
# o ferro . nenhum guerreiro
# ...

# %%
ea.analysis('books/luciola.txt')
# Out:
# quantidade de palavras: 53379
# quantidade de palavras após o filtro: 22583
# quantidade de palavras únicas: 8337
# quantidade de palavras únicas após o filtro: 7136
# 20 palavras mais frequentes:
# [('lúcia', 379), ('mim', 151), ('ainda', 128), ('mulher', 125), ('casa', 98), ('tão', 84), ('vez', 84), ('sobre', 81), ('então', 78), ('dia', 74), ('porque', 74), ('disse', 73), ('vida', 69), ('tempo', 68), ('senhor', 68), ('olhar', 63), ('sá', 62), ('prazer', 61), ('agora', 59), ('olhos', 59)]
#
#
# Palavra mais frequente: lúcia - 379 vezes
#
#
# N-grams da palavra de maior frequência
#
# seu nome : — lúcia
# nome : — lúcia !
# : — lúcia ! —
# — lúcia ! — não
# lúcia ! — não há
# eu . — a lúcia
# . — a lúcia devota
# — a lúcia devota !
# a lúcia devota ! ...
# lúcia devota ! ... bem
# coisa . quanto a lúcia
# . quanto a lúcia ,
# quanto a lúcia , fazendo-nos
# a lúcia , fazendo-nos um
# lúcia , fazendo-nos um ligeiro
# mim o encontro de lúcia
# o encontro de lúcia .
# ...

# %%
ea.analysis('books/viuvinha.txt')
# Out:
# quantidade de palavras: 20361
# quantidade de palavras após o filtro: 8896
# quantidade de palavras únicas: 4076
# quantidade de palavras únicas após o filtro: 3541
# 20 palavras mais frequentes:
# [('moço', 86), ('jorge', 71), ('carolina', 63), ('sobre', 53), ('homem', 46), ('ainda', 44), ('almeida', 42), ('havia', 38), ('velho', 38), ('tempo', 37), ('disse', 36), ('amor', 34), ('menina', 33), ('vida', 33), ('anos', 32), ('dois', 30), ('coração', 30), ('negociante', 29), ('então', 29), ('pai', 28)]
#
#
# Palavra mais frequente: moço - 86 vezes
#
#
# N-grams da palavra de maior frequência
#
# jardim encontrar-se com um moço
# encontrar-se com um moço que
# com um moço que subia
# um moço que subia a
# moço que subia a ladeira
# maria , dizia o moço
# , dizia o moço .
# dizia o moço . -
# o moço . - boa-noite
# moço . - boa-noite ,
# de despedida que o moço
# despedida que o moço imprimia
# que o moço imprimia na
# o moço imprimia na fronte
# moço imprimia na fronte cândida
# ...
